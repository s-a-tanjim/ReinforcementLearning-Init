# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import cv2
import time
import random
from tqdm.notebook import tqdm_notebook
import os
from PIL import Image

import gym
from gym import spaces
from stable_baselines3 import PPO

# %%
LOAD_MODEL = None # Path of the model or none

DISCOUNT = 0.99
REPLAY_MEMORY_SIZE = 50_000  # How many last steps to keep for model training
MIN_REPLAY_MEMORY_SIZE = 1_000  # Minimum number of steps in a memory to start training
MINIBATCH_SIZE = 64  # How many steps (samples) to use for training
UPDATE_TARGET_EVERY = 10 # 5  # Terminal states (end of episodes)
MODEL_NAME = '2x256'
MAX_TRY_IN_EPISODE = 30 # 200
MIN_REWARD = -MAX_TRY_IN_EPISODE # 0 For model save
# MEMORY_FRACTION = 0.20 # For GPU

# Environment settings
EPISODES = 5000 # 20_000

# Exploration settings
epsilon = 1  # not a constant, going to be decayed
EPSILON_DECAY = 0.9 # 0.99975
MIN_EPSILON = 0.001

#  Stats settings
AGGREGATE_STATS_EVERY = 50  # episodes

SHOW_PREVIEW = True

# For more repetitive results
random.seed(1)
np.random.seed(1)

# %%
class Blob:
    def __init__(self, size):
        self.size = size
        self.x = np.random.randint(0, size)
        self.y = np.random.randint(0, size)

    def __str__(self):
        return f"Blob ({self.x}, {self.y})"

    def __sub__(self, other):
        return (self.x-other.x, self.y-other.y)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

    def action(self, choice):
        '''
        Gives us 4 total movement options. (0,1,2,3)
        '''
        if choice == 0:
            self.move(x=1, y=0)
        elif choice == 1:
            self.move(x=-1, y=0)
        elif choice == 2:
            self.move(x=0, y=1)
        elif choice == 3:
            self.move(x=0, y=-1)


    def move(self, x=False, y=False):
        # If no value for x, move randomly
        if not x:
            self.x += np.random.randint(-1, 2)
        else:
            self.x += x

        # If no value for y, move randomly
        if not y:
            self.y += np.random.randint(-1, 2)
        else:
            self.y += y

        # If we are out of bounds, fix!
        if self.x < 0:
            self.x = 0
        elif self.x > self.size-1:
            self.x = self.size-1
        if self.y < 0:
            self.y = 0
        elif self.y > self.size-1:
            self.y = self.size-1

# %% [markdown]
# # Custom Environment

# %%
class GameEnv(gym.Env):
    """Custom Environment that follows gym interface"""
    metadata = {'render.modes': ['human']}
    SIZE = 5 # 10
    RESIZE_IMG_SIZE = 50
    RETURN_IMAGES = True
    MOVE_PENALTY = 1
    ENEMY_PENALTY = 300
    FOOD_REWARD = 25
    OBSERVATION_SPACE_VALUES = (SIZE, SIZE, 3)  # 4
    ACTION_SPACE_SIZE = 4
    PLAYER_N = 1  # player key in dict
    FOOD_N = 2  # food key in dict
    ENEMY_N = 3  # enemy key in dict
    # the dict! (colors)
    d = {1: (255, 175, 0),
         2: (0, 255, 0),
         3: (0, 0, 255)}
    
    def __init__(self):
        super(GameEnv, self).__init__()
        
        # Define action and observation space
        # They must be gym.spaces objects
        self.action_space = spaces.Discrete(self.ACTION_SPACE_SIZE)
        # Example for using image as input:
        self.observation_space = spaces.Box(low=0, high=255,
                                            shape=(self.RESIZE_IMG_SIZE, self.RESIZE_IMG_SIZE, 3), dtype=np.uint8)

    def reset(self):
        self.player = Blob(self.SIZE)
        self.food = Blob(self.SIZE)
        while self.food == self.player:
            self.food = Blob(self.SIZE)
        self.enemy = Blob(self.SIZE)
        while self.enemy == self.player or self.enemy == self.food:
            self.enemy = Blob(self.SIZE)

        self.episode_step = 0

        if self.RETURN_IMAGES:
            observation = np.array(self.get_image())
        else:
            observation = (self.player-self.food) + (self.player-self.enemy)
        return observation

    def step(self, action):
        self.episode_step += 1
        self.player.action(action)

        #### MAYBE ###
        #enemy.move()
        #food.move()
        ##############

        if self.RETURN_IMAGES:
            new_observation = np.array(self.get_image())
        else:
            new_observation = (self.player-self.food) + (self.player-self.enemy)

        if self.player == self.enemy:
            reward = -self.ENEMY_PENALTY
        elif self.player == self.food:
            reward = self.FOOD_REWARD
        else:
            reward = -self.MOVE_PENALTY

        done = False
        if reward == self.FOOD_REWARD or reward == -self.ENEMY_PENALTY or self.episode_step >= MAX_TRY_IN_EPISODE:
            cv2.waitKey(50)
            done = True
            
        self.render()

        return new_observation, reward, done, {}

    def render(self, mode='human'):
        img = self.get_image()
        img = img.resize((300, 300))  # resizing so we can see our agent in all its glory.
        cv2.imshow("image", np.array(img))  # show it!
        cv2.waitKey(1)

    # FOR CNN #
    def get_image(self):
        env = np.zeros((self.SIZE, self.SIZE, 3), dtype=np.uint8)  # starts an rbg of our size
        env[self.food.x][self.food.y] = self.d[self.FOOD_N]  # sets the food location tile to green color
        env[self.enemy.x][self.enemy.y] = self.d[self.ENEMY_N]  # sets the enemy location to red
        env[self.player.x][self.player.y] = self.d[self.PLAYER_N]  # sets the player tile to blue
        img = Image.fromarray(env, 'RGB')  # reading to rgb. Apparently. Even tho color definitions are bgr. ???
        img = img.resize((self.RESIZE_IMG_SIZE, self.RESIZE_IMG_SIZE))
        return img
    
    
    def close(self):
        self.__del__()
    
    def __del__(self):
        cv2.destroyAllWindows()

# %% [markdown]
# ## Check the env

# %%
from stable_baselines3.common.env_checker import check_env

env = GameEnv()
# It will check your custom environment and output additional warnings if needed
check_env(env)

# %% [markdown]
# # Main Loop

# %%
models_dir = f"models/ppo/{int(time.time())}/"
logdir = f"logs/ppo/{int(time.time())}/"

if not os.path.exists(models_dir):
	os.makedirs(models_dir)

if not os.path.exists(logdir):
	os.makedirs(logdir)

env = GameEnv()
env.reset()
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logdir)

TIMESTEPS = 20000
MAX_ITERS = 20 # 2000

iters = 0
while iters < MAX_ITERS:
	try:
		iters += 1
		model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="ppo")
		model.save(f"{models_dir}/{TIMESTEPS*iters}")
	
	except KeyboardInterrupt:
		env.close()
		print("Exit!")
		break
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# 2022-09-06 16:20:19.775259: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    fps             | 104      |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 14.1      |
# |    ep_rew_mean          | -127      |
# | time/                   |           |
# |    fps                  | 103       |
# |    iterations           | 2         |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0036991 |
# |    clip_fraction        | 0.00288   |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.39     |
# |    explained_variance   | 2.6e-05   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.15e+03  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.00626  |
# |    value_loss           | 1.18e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.4        |
# |    ep_rew_mean          | -87         |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 3           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011052009 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00613     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.37e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.2        |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 4           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015101102 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 8.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.5        |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 5           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015259173 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0161      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.22e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 7.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | -50.6       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 6           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017663281 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0484      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 6.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.4        |
# |    ep_rew_mean          | -43.3       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 7           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022006508 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0723      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 435         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 2.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.9        |
# |    ep_rew_mean          | -70.2       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 8           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023373727 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0287      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 805         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | -46.8       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 9           |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013793749 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.0319      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1e+03     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 3.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.7       |
# |    ep_rew_mean          | -45.3      |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 10         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01594619 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | -0.0172    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 943        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0282    |
# |    value_loss           | 2.84e+03   |
# ----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -28.9    |
# | time/              |          |
# |    fps             | 132      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | -40.1       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 2           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017183661 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 811         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 838         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | -64.1       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 3           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014621507 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 626         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 1.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | -49.6       |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 4           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013968023 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0595      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 2.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.1        |
# |    ep_rew_mean          | -50.6       |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 5           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013345679 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0724      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 853         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 1.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.6        |
# |    ep_rew_mean          | -42.1       |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 6           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013407425 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 858         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.6       |
# |    ep_rew_mean          | -22.5      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 7          |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01425906 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.979     |
# |    explained_variance   | 0.0969     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 481        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0252    |
# |    value_loss           | 1.15e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | -31.8       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 8           |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014590712 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | -0.0475     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 189         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 1.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.3        |
# |    ep_rew_mean          | -45         |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 9           |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015225373 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.0776      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 743         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 1.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.6        |
# |    ep_rew_mean          | -34.7       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 10          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015452486 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.00069     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 238         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.9     |
# |    ep_rew_mean     | -36.5    |
# | time/              |          |
# |    fps             | 127      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.9        |
# |    ep_rew_mean          | -20.9       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 2           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013343527 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 795         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | -27.9       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 3           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014474456 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | -0.221      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 595         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.1       |
# |    ep_rew_mean          | -22.5      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 4          |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01574571 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.921     |
# |    explained_variance   | -0.0543    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 71.9       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0246    |
# |    value_loss           | 996        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | -35.3       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 5           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.016353112 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.867      |
# |    explained_variance   | -0.0932     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 772         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 6           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013397933 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 241         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 7           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012680001 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 986         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | -22.3       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 8           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014834186 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 303         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 962         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.7         |
# |    ep_rew_mean          | -24.8        |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 9            |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0146820815 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# |    explained_variance   | -0.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 275          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0287      |
# |    value_loss           | 631          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.1        |
# |    ep_rew_mean          | -30.7       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 10          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014749708 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.0255      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 847         |
# -----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17       |
# |    ep_rew_mean     | -13.7    |
# | time/              |          |
# |    fps             | 122      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.9        |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 2           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017731022 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 436         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | -27.3       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 3           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.013030341 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | -0.0322     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 625         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 878         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 4           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015413326 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 820         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18         |
# |    ep_rew_mean          | -30.8      |
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 5          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01696629 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.179      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 201        |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0282    |
# |    value_loss           | 746        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.5        |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 6           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013752863 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | -0.051      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 446         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 612         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | -35.6       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 7           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012982221 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | -0.0362     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 651         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | -26.3       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 8           |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013989612 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.826      |
# |    explained_variance   | -0.0632     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 287         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 901         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.5        |
# |    ep_rew_mean          | -34.2       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 9           |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013968117 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 626         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.8        |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 10          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014747083 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | 0.0601      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 661         |
# -----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.7     |
# |    ep_rew_mean     | -15.5    |
# | time/              |          |
# |    fps             | 120      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 83968    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.2       |
# |    ep_rew_mean          | -44.5      |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 2          |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01858736 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.776     |
# |    explained_variance   | -0.126     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 90.3       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0257    |
# |    value_loss           | 723        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.3        |
# |    ep_rew_mean          | -21.3       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 3           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012948801 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.0452      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 373         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 1.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.4        |
# |    ep_rew_mean          | -35.3       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 4           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012540817 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | -0.205      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 228         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.023      |
# |    value_loss           | 839         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.5        |
# |    ep_rew_mean          | -35.3       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 5           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.014310911 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | -0.0512     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 478         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 906         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.7        |
# |    ep_rew_mean          | -43.9       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 6           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011768649 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.0854      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 537         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.4        |
# |    ep_rew_mean          | -39.9       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 7           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013798294 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | -0.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 180         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.5        |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 8           |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012307665 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 303         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0238     |
# |    value_loss           | 739         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | -25.6      |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 9          |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01816634 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.779     |
# |    explained_variance   | -0.278     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.2       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.024     |
# |    value_loss           | 496        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | -17.8       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 10          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013614073 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.0257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 473         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 969         |
# -----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.4     |
# |    ep_rew_mean     | -27.9    |
# | time/              |          |
# |    fps             | 118      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 104448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 2           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.016514674 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | -0.106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 685         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.5       |
# |    ep_rew_mean          | -39.5      |
# | time/                   |            |
# |    fps                  | 108        |
# |    iterations           | 3          |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.01677877 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.745     |
# |    explained_variance   | -0.213     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 52.9       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0249    |
# |    value_loss           | 631        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.3        |
# |    ep_rew_mean          | -22.9       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 4           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.012936857 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.0401      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 365         |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 5           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.013801427 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 231         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 748         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.1        |
# |    ep_rew_mean          | -28.6       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 6           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.018192321 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | -0.000162   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 599         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -28.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 7           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.017470535 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | -0.0461     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 687         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.7         |
# |    ep_rew_mean          | -19.7        |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 8            |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0139297545 |
# ...
# |    ep_rew_mean          | -17.3      |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 2          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 372736     |
# | train/                  |            |
# |    approx_kl            | 0.02198238 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.569     |
# |    explained_variance   | 0.0854     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14e+03   |
# |    n_updates            | 1810       |
# |    policy_gradient_loss | -0.0227    |
# |    value_loss           | 1.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.1         |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 3           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.012225679 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | -0.0612     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 604         |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 1.78e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.71      |
# |    ep_rew_mean          | -17.7     |
# | time/                   |           |
# |    fps                  | 76        |
# |    iterations           | 4         |
# |    time_elapsed         | 106       |
# |    total_timesteps      | 376832    |
# | train/                  |           |
# |    approx_kl            | 0.0172727 |
# |    clip_fraction        | 0.104     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.557    |
# |    explained_variance   | -0.493    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 364       |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | -0.0197   |
# |    value_loss           | 1.69e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.52        |
# |    ep_rew_mean          | -1.54       |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.038182303 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | -0.0275     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.2        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.53        |
# |    ep_rew_mean          | -2.55       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 6           |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.012296155 |
# |    clip_fraction        | 0.0988      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -0.186      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 485         |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.16        |
# |    ep_rew_mean          | 9.78        |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 7           |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.025105549 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.5        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.69        |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 8           |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.027591836 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.56       |
# |    ep_rew_mean          | -11.6      |
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 9          |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 387072     |
# | train/                  |            |
# |    approx_kl            | 0.01431019 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.57      |
# |    explained_variance   | 0.135      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 94.8       |
# |    n_updates            | 1880       |
# |    policy_gradient_loss | -0.0224    |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.15        |
# |    ep_rew_mean          | -17.7       |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 10          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.015087055 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 424         |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 1.42e+03    |
# -----------------------------------------
# Logging to logs/ppo/1662459619/ppo_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.79     |
# |    ep_rew_mean     | -7.1     |
# | time/              |          |
# |    fps             | 89       |
# |    iterations      | 1        |
# |    time_elapsed    | 22       |
# |    total_timesteps | 391168   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.8         |
# |    ep_rew_mean          | 4.68        |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 2           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.019425407 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | -0.0921     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62          |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.25       |
# |    ep_rew_mean          | 8.69       |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 3          |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.03623399 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.52      |
# |    explained_variance   | -0.163     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 509        |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.79        |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 4           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.022195123 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | -0.192      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 693         |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.79       |
# |    ep_rew_mean          | -12.3      |
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 5          |
# |    time_elapsed         | 123        |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.03266088 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.553     |
# |    explained_variance   | -0.134     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34         |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | -0.0186    |
# |    value_loss           | 1.1e+03    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.78       |
# |    ep_rew_mean          | 5.65       |
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 6          |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.01627766 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | -0.0267    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 103        |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 1.61e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.3         |
# |    ep_rew_mean          | -9.86       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 7           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 403456      |
# | train/                  |             |
# |    approx_kl            | 0.037173636 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | -0.0887     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 364         |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 910         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.17        |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 8           |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 405504      |
# | train/                  |             |
# |    approx_kl            | 0.013653224 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 1.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.88        |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 9           |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 407552      |
# | train/                  |             |
# |    approx_kl            | 0.019762069 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | -0.0739     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 603         |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.13        |
# |    ep_rew_mean          | -2.15       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 10          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.024998266 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.0938      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
